# %% [markdown]
# <a href="https://colab.research.google.com/github/maniratnam256/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain lambda function.'
)
print(resp.text)
# Out:
# A **lambda function** (also known as an "anonymous function") is a small, unnamed function defined in a single line of code. It's a way to create simple functions on the fly, often used for short, one-time operations.
#
# Think of it like a quick sticky note for a function – you write down the inputs and what you want to compute, and you don't bother giving it a formal name because you only need it for a moment.
#
# ---
#
# ### Key Characteristics of Lambda Functions:
#
# 1.  **Anonymous:** They don't have a name like regular functions defined with the `def` keyword.
# 2.  **Single Expression:** They can only contain one expression. The result of this expression is implicitly returned. You cannot have multiple statements, loops (`for`, `while`), or complex conditional blocks (`if/elif/else` statements) directly within a lambda function's body (though you can use a ternary operator for simple conditions).
# ...
